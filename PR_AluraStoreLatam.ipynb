# %% [markdown]
# <a href="https://colab.research.google.com/github/Pauw1/Challenge_Alura_Store_Python_para_Data_Science/blob/main/PR_AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# # **Datos de las Tiendas a Analizar**

# %% [markdown]
# **Tienda 1**

# %%
tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# **Tienda 2**

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %% [markdown]
# **Tienda 3**

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %% [markdown]
# **Tienda 4**

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# Facturación total Tienda 1

# %%
total_ventas_t1 = sum(tienda.Precio)
print(f"La facturación total de la tienda 1 es: {total_ventas_t1}")
# Out:
# La facturación total de la tienda 1 es: 1150880400.0

# %% [markdown]
# Facturación total Tienda 2

# %%
total_ventas_t2 = sum(tienda2.Precio)
print(f"La facturación total de la tienda 2 es: {total_ventas_t2}")
# Out:
# La facturación total de la tienda 2 es: 1116343500.0

# %% [markdown]
# Facturación total Tienda 3

# %%
total_ventas_t3 = sum(tienda3.Precio)
print(f"La facturación total de la tienda 3 es: {total_ventas_t3}")
# Out:
# La facturación total de la tienda 3 es: 1098019600.0

# %% [markdown]
# Facturación total Tienda 4

# %%
total_ventas_t4 = sum(tienda4.Precio)
print(f"La facturación total de la tienda 4 es: {total_ventas_t4}")
# Out:
# La facturación total de la tienda 4 es: 1038375700.0

# %% [markdown]
# **Gráfico: Comparación de facturaciones totales de cada tienda**

# %%
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas_totales = [total_ventas_t1, total_ventas_t2, total_ventas_t3, total_ventas_t4]
plt.bar(nombres_tiendas, ventas_totales, color='pink')
plt.xlabel("Tiendas")
plt.ylabel("Divisa")
plt.title("Total Facturado por Tienda")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# **Cantidad de Ventas Tienda 1**

# %%
tienda.columns = tienda.columns.str.replace("Categoría del Producto","Categoria")

# %%
conteo_productos = tienda['Categoria'].value_counts()
conteo_productos
# Out:
# Categoria
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
# Datos para el gráfico
categorias = tienda.Categoria.value_counts().index
valores = tienda.Categoria.value_counts().values

# Crear el gráfico de barras horizontal
plt.barh(categorias, valores)

# Añadir título y etiquetas a los ejes
plt.title('Ventas por Categoría en Tienda 1')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Categorías de Productos')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Cantidad de Ventas Tienda 2**

# %%
tienda2.columns = tienda2.columns.str.replace("Categoría del Producto","Categoria")

# %%
conteo_productos2 = tienda2['Categoria'].value_counts()
conteo_productos2
# Out:
# Categoria
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
# Datos para el gráfico
categorias = tienda2.Categoria.value_counts().index
valores = tienda2.Categoria.value_counts().values

# Crear el gráfico de barras horizontal
plt.barh(categorias, valores)

# Añadir título y etiquetas a los ejes
plt.title('Ventas por Categoría en Tienda 2')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Categorías de Productos')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Cantidad de Ventas Tienda 3**

# %%
tienda3.columns = tienda3.columns.str.replace("Categoría del Producto","Categoria")

# %%
conteo_productos3 = tienda3['Categoria'].value_counts()
conteo_productos3
# Out:
# Categoria
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
# Datos para el gráfico
categorias = tienda3.Categoria.value_counts().index
valores = tienda3.Categoria.value_counts().values

# Crear el gráfico de barras horizontal
plt.barh(categorias, valores)

# Añadir título y etiquetas a los ejes
plt.title('Ventas por Categoría en Tienda 3')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Categorías de Productos')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Cantidad de Ventas Tienda 4**

# %%
tienda4.columns = tienda4.columns.str.replace("Categoría del Producto","Categoria")

# %%
conteo_productos4 = tienda4['Categoria'].value_counts()
conteo_productos4
# Out:
# Categoria
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
# Datos para el gráfico
categorias = tienda4.Categoria.value_counts().index
valores = tienda4.Categoria.value_counts().values

# Crear el gráfico de barras horizontal
plt.barh(categorias, valores)

# Añadir título y etiquetas a los ejes
plt.title('Ventas por Categoría en Tienda 4')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Categorías de Productos')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Comparativa de los gráficos de venta por categoría**

# %%
# Crear una figura con 4 subgráficos (2 filas x 2 columnas)
fig, axs = plt.subplots(2, 2, figsize=(12,10))

# --- Gráfico 1 (Tienda 1) ---
categorias1 = tienda.Categoria.value_counts().index
valores1 = tienda.Categoria.value_counts().values
axs[0,0].barh(categorias1, valores1, color='skyblue')
axs[0,0].set_title('Ventas por Categoría - Tienda 1')
axs[0,0].set_xlabel('Cantidad de Ventas')
axs[0,0].set_ylabel('Categorías de Productos')

# --- Gráfico 2 (Tienda 2) ---
categorias2 = tienda2.Categoria.value_counts().index
valores2 = tienda2.Categoria.value_counts().values
axs[0,1].barh(categorias2, valores2, color='lightgreen')
axs[0,1].set_title('Ventas por Categoría - Tienda 2')
axs[0,1].set_xlabel('Cantidad de Ventas')
axs[0,1].set_ylabel('Categorías de Productos')

# --- Gráfico 3 (Tienda 3) ---
categorias3 = tienda3.Categoria.value_counts().index
valores3 = tienda3.Categoria.value_counts().values
axs[1,0].barh(categorias3, valores3, color='salmon')
axs[1,0].set_title('Ventas por Categoría - Tienda 3')
axs[1,0].set_xlabel('Cantidad de Ventas')
axs[1,0].set_ylabel('Categorías de Productos')

# --- Gráfico 4 (Tienda 4) ---
categorias4 = tienda4.Categoria.value_counts().index
valores4 = tienda4.Categoria.value_counts().values
axs[1,1].barh(categorias4, valores4, color='orange')
axs[1,1].set_title('Ventas por Categoría - Tienda 4')
axs[1,1].set_xlabel('Cantidad de Ventas')
axs[1,1].set_ylabel('Categorías de Productos')

# Ajustar diseño para que las etiquetas no se sobrepongan
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# **Calificación Promedio Tienda 1**

# %%
calificacion_promedio_t1 = sum(tienda['Calificación'])/len(tienda['Calificación'])
calificacion_promedio_t1_redondeado = round(calificacion_promedio_t1, 2)
print(f"La calificación promedio de la tienda 1 es: {calificacion_promedio_t1_redondeado}")
# Out:
# La calificación promedio de la tienda 1 es: 3.98

# %%
#Método alternativo de confirmación
calificacion_prom_t1 = tienda['Calificación'].mean()
calificacion_prom_t1_redondeada = round(calificacion_prom_t1, 2)
print(f"La calificación promedio de la tienda 1 es: {calificacion_prom_t1_redondeada}")
# Out:
# La calificación promedio de la tienda 1 es: 3.98

# %% [markdown]
# **Calificación Promedio Tienda 2**

# %%
calificacion_promedio_t2 = sum(tienda2['Calificación'])/len(tienda2['Calificación'])
calificacion_promedio_t2_redondeado = round(calificacion_promedio_t2, 2)
print(f"La calificación promedio de la tienda 2 es: {calificacion_promedio_t2_redondeado}")
# Out:
# La calificación promedio de la tienda 2 es: 4.04

# %% [markdown]
# **Calificación Promedio Tienda 3**

# %%
calificacion_promedio_t3 = sum(tienda3['Calificación'])/len(tienda3['Calificación'])
calificacion_promedio_t3_redondeado = round(calificacion_promedio_t3, 2)
print(f"La calificación promedio de la tienda 3 es: {calificacion_promedio_t3_redondeado}")
# Out:
# La calificación promedio de la tienda 3 es: 4.05

# %% [markdown]
# **Calificación Promedio Tienda 4**

# %%
calificacion_promedio_t4 = sum(tienda4['Calificación'])/len(tienda4['Calificación'])
calificacion_promedio_t4_redondeado = round(calificacion_promedio_t4, 2)
print(f"La calificación promedio de la tienda 4 es: {calificacion_promedio_t4_redondeado}")
# Out:
# La calificación promedio de la tienda 4 es: 4.0

# %% [markdown]
# **Gráfico comparativo de las Calificaciones Promedio por tienda**

# %%
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificaciones	= [calificacion_promedio_t1_redondeado, calificacion_promedio_t2_redondeado, calificacion_promedio_t3_redondeado, calificacion_promedio_t4_redondeado]

# %%
plt.bar(x=tiendas, height=calificaciones, color='green')
plt.xlabel("Tiendas")
plt.ylabel("Calificación Promedio")
plt.title("Calificación Promedio por Tienda")
plt.tight_layout()

plt.show()

# %% [markdown]
# **Visualización ajustada para ver diferencias sutiles.**

# %%
plt.bar(x=tiendas, height=calificaciones, color='green')
plt.xlabel("Tiendas")
plt.ylabel("Calificación Promedio")
plt.title("Calificación Promedio por Tienda (diferencia ajustada)")
plt.tight_layout()
plt.ylim(3.9, 4.1)

plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# **Productos Tienda 1**

# %%
tienda.Producto.value_counts()
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
total_ventas_productos_t1 = tienda.Producto.value_counts().sum()
total_ventas_productos
# Out:
# np.int64(2359)

# %%
tienda1_masvendido = tienda.Producto.value_counts().idxmax()
tienda1_menosvendido = tienda.Producto.value_counts().idxmin()
print(f"El producto más vendido de la tienda 1 es: {tienda1_masvendido}")
print(f"El producto menos vendido de la tienda 1 es: {tienda1_menosvendido}")
# Out:
# El producto más vendido de la tienda 1 es: Microondas
# El producto menos vendido de la tienda 1 es: Auriculares con micrófono

# %%
masvendidot1 = tienda['Producto'].value_counts()['Microondas']
print(f"El producto Microondas se vendió {masvendidot1} veces")
# Out:
# El producto Microondas se vendió 60 veces

# %%
menosvendidot1 = tienda['Producto'].value_counts()['Auriculares con micrófono']
print(f"El producto Auriculares con micrófono se vendió {menosvendidot1} veces")
# Out:
# El producto Auriculares con micrófono se vendió 33 veces

# %% [markdown]
# **Productos Tienda 2**

# %%
tienda2.Producto.value_counts()
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
total_ventas_productos_t2 = tienda2.Producto.value_counts().sum()
total_ventas_productos_t2
# Out:
# np.int64(2359)

# %%
prod2 = tienda2['Producto'].value_counts().sum()
prod2
# Out:
# np.int64(2359)

# %%
tienda2_masvendido = tienda2.Producto.value_counts().idxmax()
tienda2_menosvendido = tienda2.Producto.value_counts().idxmin()
print(f"El producto más vendido de la tienda 2 es: {tienda2_masvendido}")
print(f"El producto menos vendido de la tienda 2 es: {tienda2_menosvendido}")
# Out:
# El producto más vendido de la tienda 2 es: Iniciando en programación
# El producto menos vendido de la tienda 2 es: Juego de mesa

# %%
masvendidot2 = tienda2['Producto'].value_counts()['Iniciando en programación']
menosvendidot2 = tienda2['Producto'].value_counts()['Juego de mesa']
print(f"El producto Iniciando en programación se vendió {masvendidot2} veces")
print(f"El producto Juego de mesa se vendió {menosvendidot2} veces")
# Out:
# El producto Iniciando en programación se vendió 65 veces
# El producto Juego de mesa se vendió 32 veces

# %% [markdown]
# **Productos Tienda 3**

# %%
tienda3.Producto.value_counts()
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
tienda3_masvendido = tienda3.Producto.value_counts().idxmax()
tienda3_menosvendido = tienda3.Producto.value_counts().idxmin()
print(f"El producto más vendido de la tienda 3 es: {tienda3_masvendido}")
print(f"El producto menos vendido de la tienda 3 es: {tienda3_menosvendido}")
# Out:
# El producto más vendido de la tienda 3 es: Kit de bancas
# El producto menos vendido de la tienda 3 es: Bloques de construcción

# %%
masvendidot3 = tienda3['Producto'].value_counts()['Kit de bancas']
menosvendidot3 = tienda3['Producto'].value_counts()['Bloques de construcción']
print(f"El producto Kit de bancas se vendió {masvendidot3} veces")
print(f"El producto Bloques de construcción se vendió {menosvendidot3} veces")
# Out:
# El producto Kit de bancas se vendió 57 veces
# El producto Bloques de construcción se vendió 35 veces

# %% [markdown]
# **Productos Tienda 4**

# %%
tienda4.Producto.value_counts()
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %%
tienda4_masvendido = tienda4.Producto.value_counts().idxmax()
tienda4_menosvendido = tienda4.Producto.value_counts().idxmin()
print(f"El producto más vendido de la tienda 4 es: {tienda4_masvendido}")
print(f"El producto menos vendido de la tienda 4 es: {tienda4_menosvendido}")
# Out:
# El producto más vendido de la tienda 4 es: Cama box
# El producto menos vendido de la tienda 4 es: Guitarra eléctrica

# %%
masvendidot4 = tienda4['Producto'].value_counts()['Cama box']
menosvendidot4 = tienda4['Producto'].value_counts()['Guitarra eléctrica']
print(f"El producto Cama box se vendió {masvendidot4} veces")
print(f"El producto Guitarra eléctrica se vendió {menosvendidot4} veces")
# Out:
# El producto Cama box se vendió 62 veces
# El producto Guitarra eléctrica se vendió 33 veces

# %% [markdown]
# **Gráfico de Productos Más y Menos Vendidos por tienda**

# %%
print(f'{tienda1_masvendido} se vendió {masvendidot1} veces')
print(f'{tienda1_menosvendido} se vendió {menosvendidot1} veces')
print(f'{tienda2_masvendido} se vendió {masvendidot2} veces')
print(f'{tienda2_menosvendido} se vendió {menosvendidot2} veces')
print(f'{tienda3_masvendido} se vendió {masvendidot3} veces')
print(f'{tienda3_menosvendido} se vendió {menosvendidot3} veces')
print(f'{tienda4_masvendido} se vendió {masvendidot4} veces')
print(f'{tienda4_menosvendido} se vendió {menosvendidot4} veces')
# Out:
# Microondas se vendió 60 veces
# Auriculares con micrófono se vendió 33 veces
# Iniciando en programación se vendió 65 veces
# Juego de mesa se vendió 32 veces
# Kit de bancas se vendió 57 veces
# Bloques de construcción se vendió 35 veces
# Cama box se vendió 62 veces
# Guitarra eléctrica se vendió 33 veces

# %%
labels = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
mas_vendidos = [60, 65, 57, 62]
menos_vendidos = [33, 32, 35, 33]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, mas_vendidos, width, label='Más vendidos')
rects2 = ax.bar(x + width/2, menos_vendidos, width, label='Menos vendidos')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Cantidad Vendida')
ax.set_title('Productos Más y Menos Vendidos por Tienda')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# **Envío promedio Tienda 1**

# %%
envio_promedio_t1 = tienda['Costo de envío'].mean()
envio_promedio_t1_redondeado = round(envio_promedio_t1, 2)

print('El envío promedio de la tienda 1 es:', envio_promedio_t1_redondeado)
# Out:
# El envío promedio de la tienda 1 es: 26018.61

# %% [markdown]
# **Envío promedio Tienda 2**

# %%
envio_promedio_t2 = tienda2['Costo de envío'].mean()
envio_promedio_t2_redondeado = round(envio_promedio_t2, 2)

print(envio_promedio_t2_redondeado)
# Out:
# 25216.24

# %% [markdown]
# **Envío promedio Tienda 3**

# %%
envio_promedio_t3 = tienda3['Costo de envío'].mean()
envio_promedio_t3_redondeado = round(envio_promedio_t3, 2)

print(envio_promedio_t3_redondeado)
# Out:
# 24805.68

# %% [markdown]
# **Envío promedio Tienda 4**

# %%
envio_promedio_t4 = tienda4['Costo de envío'].mean()
envio_promedio_t4_redondeado = round(envio_promedio_t4, 2)

print(envio_promedio_t4_redondeado)
# Out:
# 23459.46

# %% [markdown]
# **Gráfico con el promedio de envíos por tienda**

# %%
envio_promedio_tiendas = [envio_promedio_t1_redondeado, envio_promedio_t2_redondeado, envio_promedio_t3_redondeado, envio_promedio_t4_redondeado]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.bar(x=tiendas, height=envio_promedio_tiendas, color='red')
plt.xlabel("Tiendas")
plt.ylabel("Envío Promedio")
plt.title("Envío Promedio por Tienda")
# Out:
# Text(0.5, 1.0, 'Envío Promedio por Tienda')

# %% [markdown]
# Cálculo de Rendimiento

# %% [markdown]
# Facturación total:

# %%
Total_facturaciones_AluraStore = sum(tienda.Precio) + sum(tienda2.Precio) + sum(tienda3.Precio) + sum(tienda4.Precio)
print(f"La facturación total de las tiendas es: {Total_facturaciones_AluraStore}")
# Out:
# La facturación total de las tiendas es: 4403619200.0

# %%
Rendimiento_FT1 = sum(tienda.Precio)/Total_facturaciones_AluraStore
print(f"El rendimiento por facturaciones de la tienda 1 es: {Rendimiento_FT1}")
Rendimiento_FT2 = sum(tienda2.Precio)/Total_facturaciones_AluraStore
print(f"El rendimiento por facturaciones de la tienda 2 es: {Rendimiento_FT2}")
Rendimiento_FT3 = sum(tienda3.Precio)/Total_facturaciones_AluraStore
print(f"El rendimiento por facturaciones de la tienda 3 es: {Rendimiento_FT3}")
Rendimiento_FT4 = sum(tienda4.Precio)/Total_facturaciones_AluraStore
print(f"El rendimiento por facturaciones de la tienda 4 es: {Rendimiento_FT4}")
# Out:
# El rendimiento por facturaciones de la tienda 1 es: 0.2613487560413943
# El rendimiento por facturaciones de la tienda 2 es: 0.2535059116828267
# El rendimiento por facturaciones de la tienda 3 es: 0.24934481164947234
# El rendimiento por facturaciones de la tienda 4 es: 0.23580052062630666

# %% [markdown]
# **Rendimiento por cantidad de ventas**

# %%
MueblesT1 = 465
ElectronicosT1 = 448
InstrumentosT1 =182
LibrosT1 = 173
ArtHogarT1 =171

MueblesT2 = 442
ElectronicosT2 = 422
InstrumentosT2 = 224
LibrosT2 = 197
ArtHogarT2 = 181

MueblesT3 = 499
ElectronicosT3 = 451
InstrumentosT3 = 177
LibrosT3 = 185
ArtHogarT3 = 177

MueblesT4 = 480
ElectronicosT4 = 451
InstrumentosT4 = 201
LibrosT4 = 187
ArtHogarT4 = 170

# %%
total_ventas_categorias1 = sum(tienda.Categoria.value_counts())
total_ventas_categorias2 = sum(tienda2.Categoria.value_counts())
total_ventas_categorias3 = sum(tienda3.Categoria.value_counts())
total_ventas_categorias4 = sum(tienda4.Categoria.value_counts())

total_ventas_categorias = total_ventas_categorias1 + total_ventas_categorias2 + total_ventas_categorias3 + total_ventas_categorias4
print(f"El total de ventas de categorías de las tiendas es: {total_ventas_categorias}")

print('Total de ventas de todas las categorías de la tienda 1:', total_ventas_categorias1)
print('Total de ventas de todas las categorías de la tienda 2:', total_ventas_categorias2)
print('Total de ventas de todas las categorías de la tienda 3:', total_ventas_categorias3)
print('Total de ventas de todas las categorías de la tienda 4:', total_ventas_categorias4)

total_ventas_categorias = (total_ventas_categorias1 + total_ventas_categorias2 + total_ventas_categorias3 + total_ventas_categorias4)

Rendimiento_CV1 = total_ventas_categorias1/total_ventas_categorias
Rendimiento_CV2 = total_ventas_categorias2/total_ventas_categorias
Rendimiento_CV3 = total_ventas_categorias3/total_ventas_categorias
Rendimiento_CV4 = total_ventas_categorias4/total_ventas_categorias

print(f"El rendimiento por ventas de la tienda 1 es: {Rendimiento_CV1}")
print(f"El rendimiento por ventas de la tienda 2 es: {Rendimiento_CV2}")
print(f"El rendimiento por ventas de la tienda 3 es: {Rendimiento_CV3}")
print(f"El rendimiento por ventas de la tienda 4 es: {Rendimiento_CV4}")
# Out:
# El total de ventas de categorías de las tiendas es: 9435
# Total de ventas de todas las categorías de la tienda 1: 2359
# Total de ventas de todas las categorías de la tienda 2: 2359
# Total de ventas de todas las categorías de la tienda 3: 2359
# Total de ventas de todas las categorías de la tienda 4: 2358
# El rendimiento por ventas de la tienda 1 es: 0.2500264970853206
# El rendimiento por ventas de la tienda 2 es: 0.2500264970853206
# El rendimiento por ventas de la tienda 3 es: 0.2500264970853206
# El rendimiento por ventas de la tienda 4 es: 0.24992050874403815

# %% [markdown]
# **Rendimiento por calificación promedio de la tienda**

# %%
calificacion_promedio_total = (calificacion_promedio_t1_redondeado + calificacion_promedio_t2_redondeado + calificacion_promedio_t3_redondeado + calificacion_promedio_t4_redondeado)/4
print(f"El rendimiento por calificación promedio de las tiendas es: {calificacion_promedio_total}")

rendimiento_calificacion_t1 = calificacion_promedio_t1_redondeado/(calificacion_promedio_t1_redondeado+calificacion_promedio_t2_redondeado+calificacion_promedio_t3_redondeado+calificacion_promedio_t4_redondeado)
rendimiento_calificacion_t2 = calificacion_promedio_t2_redondeado/(calificacion_promedio_t1_redondeado+calificacion_promedio_t2_redondeado+calificacion_promedio_t3_redondeado+calificacion_promedio_t4_redondeado)
rendimiento_calificacion_t3 = calificacion_promedio_t3_redondeado/(calificacion_promedio_t1_redondeado+calificacion_promedio_t2_redondeado+calificacion_promedio_t3_redondeado+calificacion_promedio_t4_redondeado)
rendimiento_calificacion_t4 = calificacion_promedio_t4_redondeado/(calificacion_promedio_t1_redondeado+calificacion_promedio_t2_redondeado+calificacion_promedio_t3_redondeado+calificacion_promedio_t4_redondeado)

print('El rendimiento de calificación promedio de la tienda 1 es:', rendimiento_calificacion_t1)
print('El rendimiento de calificación promedio de la tienda 2 es:', rendimiento_calificacion_t2)
print('El rendimiento de calificación promedio de la tienda 3 es:', rendimiento_calificacion_t3)
print('El rendimiento de calificación promedio de la tienda 4 es:', rendimiento_calificacion_t4)
# Out:
# El rendimiento por calificación promedio de las tiendas es: 4.0175
# El rendimiento de calificación promedio de la tienda 1 es: 0.2476664592408214
# El rendimiento de calificación promedio de la tienda 2 es: 0.25140012445550713
# El rendimiento de calificación promedio de la tienda 3 es: 0.2520224019912881
# El rendimiento de calificación promedio de la tienda 4 es: 0.24891101431238333

# %% [markdown]
# Rendimiento por ventas de productos

# %%
total_ventas_productos = sum(tienda.Producto.value_counts()) + sum(tienda2.Producto.value_counts()) + sum(tienda3.Producto.value_counts()) + sum(tienda4.Producto.value_counts())
print(f"El total de ventas de productos es: {total_ventas_productos}")

Rendimiento_PV1 = sum(tienda.Producto.value_counts())/total_ventas_productos
Rendimiento_PV2 = sum(tienda2.Producto.value_counts())/total_ventas_productos
Rendimiento_PV3 = sum(tienda3.Producto.value_counts())/total_ventas_productos
Rendimiento_PV4 = sum(tienda4.Producto.value_counts())/total_ventas_productos


print('El rendimiento de ventas de productos de la tienda 1 es:', Rendimiento_PV1)
print('El rendimiento de ventas de productos de la tienda 2 es:', Rendimiento_PV2)
print('El rendimiento de ventas de productos de la tienda 3 es:', Rendimiento_PV3)
print('El rendimiento de ventas de productos de la tienda 4 es:', Rendimiento_PV4)
# Out:
# El total de ventas de productos es: 9435
# El rendimiento de ventas de productos de la tienda 1 es: 0.2500264970853206
# El rendimiento de ventas de productos de la tienda 2 es: 0.2500264970853206
# El rendimiento de ventas de productos de la tienda 3 es: 0.2500264970853206
# El rendimiento de ventas de productos de la tienda 4 es: 0.24992050874403815

# %% [markdown]
# Rendimiento por Costo de Envíos Promedio

# %%
facturacion_promedio_t1 = tienda.Precio.mean()
facturacion_promedio_t2 = tienda2.Precio.mean()
facturacion_promedio_t3 = tienda3.Precio.mean()
facturacion_promedio_t4 = tienda4.Precio.mean()

print(f"La facturación promedio de la tienda 1 es: {facturacion_promedio_t1}")
print(f"La facturación promedio de la tienda 2 es: {facturacion_promedio_t2}")
print(f"La facturación promedio de la tienda 3 es: {facturacion_promedio_t3}")
print(f"La facturación promedio de la tienda 4 es: {facturacion_promedio_t4}")

facturacion_menos_envio_promedio_t1 = facturacion_promedio_t1 - envio_promedio_t1
facturacion_menos_envio_promedio_t2 = facturacion_promedio_t2 - envio_promedio_t2
facturacion_menos_envio_promedio_t3 = facturacion_promedio_t3 - envio_promedio_t3
facturacion_menos_envio_promedio_t4 = facturacion_promedio_t4 - envio_promedio_t4

print(f"La diferencia entre la facturación promedio y el envío promedio de la tienda 1 es: {facturacion_menos_envio_promedio_t1}")
print(f"La diferencia entre la facturación promedio y el envío promedio de la tienda 2 es: {facturacion_menos_envio_promedio_t2}")
print(f"La diferencia entre la facturación promedio y el envío promedio de la tienda 3 es: {facturacion_menos_envio_promedio_t3}")
print(f"La diferencia entre la facturación promedio y el envío promedio de la tienda 4 es: {facturacion_menos_envio_promedio_t4}")
# Out:
# La facturación promedio de la tienda 1 es: 487867.9101314116
# La facturación promedio de la tienda 2 es: 473227.42687579483
# La facturación promedio de la tienda 3 es: 465459.7710894447
# La facturación promedio de la tienda 4 es: 440362.89228159457
# La diferencia entre la facturación promedio y el envío promedio de la tienda 1 es: 461849.30055108096
# La diferencia entre la facturación promedio y el envío promedio de la tienda 2 es: 448011.1911827045
# La diferencia entre la facturación promedio y el envío promedio de la tienda 3 es: 440654.09071640525
# La diferencia entre la facturación promedio y el envío promedio de la tienda 4 es: 416903.43511450384

# %%
envio_total_t1 = tienda['Costo de envío'].sum()
envio_total_t2 = tienda2['Costo de envío'].sum()
envio_total_t3 = tienda3['Costo de envío'].sum()
envio_total_t4 = tienda4['Costo de envío'].sum()

print(f"El envío total de la tienda 1 es: {envio_total_t1}")
print(f"El envío total de la tienda 2 es: {envio_total_t2}")
print(f"El envío total de la tienda 3 es: {envio_total_t3}")
print(f"El envío total de la tienda 4 es: {envio_total_t4}")

envio_total_total = envio_total_t1 + envio_total_t2 + envio_total_t3 + envio_total_t4

facturacion_menos_envio_totales = Total_facturaciones_AluraStore - envio_total_total
print(f"La facturacion total menos el costo total de envio de AluraStore Latam es: {facturacion_menos_envio_totales}")

Rendimiento_F_menos_envios_t1 = (tienda.Precio.sum() - envio_total_t1)/Total_facturaciones_AluraStore
Rendimiento_F_menos_envios_t2 = (tienda2.Precio.sum() - envio_total_t2)/Total_facturaciones_AluraStore
Rendimiento_F_menos_envios_t3 = (tienda3.Precio.sum() - envio_total_t3)/Total_facturaciones_AluraStore
Rendimiento_F_menos_envios_t4 = (tienda4.Precio.sum() - envio_total_t4)/Total_facturaciones_AluraStore

Facturacion_menos_envio_t1 = tienda.Precio.sum() - envio_total_t1
Facturacion_menos_envio_t2 = tienda2.Precio.sum() - envio_total_t2
Facturacion_menos_envio_t3 = tienda3.Precio.sum() - envio_total_t3
Facturacion_menos_envio_t4 = tienda4.Precio.sum() - envio_total_t4

print(f'La facturación menos el costo de envío de la tienda 1 es: {Facturacion_menos_envio_t1}')
print(f'La facturación menos el costo de envío de la tienda 2 es: {Facturacion_menos_envio_t2}')
print(f'La facturación menos el costo de envío de la tienda 3 es: {Facturacion_menos_envio_t3}')
print(f'La facturación menos el costo de envío de la tienda 4 es: {Facturacion_menos_envio_t4}')

print(f"El rendimiento por facturación de la tienda 1 es: {Rendimiento_F_menos_envios_t1}")
print(f"El rendimiento por facturación de la tienda 2 es: {Rendimiento_F_menos_envios_t2}")
print(f"El rendimiento por facturación de la tienda 3 es: {Rendimiento_F_menos_envios_t3}")
print(f"El rendimiento por facturación de la tienda 4 es: {Rendimiento_F_menos_envios_t4}")
# Out:
# El envío total de la tienda 1 es: 61377900.0
# El envío total de la tienda 2 es: 59485100.0
# El envío total de la tienda 3 es: 58516600.0
# El envío total de la tienda 4 es: 55317400.0
# La facturacion total menos el costo total de envio de AluraStore Latam es: 4168922200.0
# La facturación menos el costo de envío de la tienda 1 es: 1089502500.0
# La facturación menos el costo de envío de la tienda 2 es: 1056858400.0
# La facturación menos el costo de envío de la tienda 3 es: 1039503000.0
# La facturación menos el costo de envío de la tienda 4 es: 983058300.0
# El rendimiento por facturación de la tienda 1 es: 0.24741069800040838
# El rendimiento por facturación de la tienda 2 es: 0.23999768190673706
# El rendimiento por facturación de la tienda 3 es: 0.23605651460507757
# El rendimiento por facturación de la tienda 4 es: 0.2232387169172121

# %% [markdown]
# **Rendimiento Total por tienda**

# %%
valoresT1Y = [0.2613487560413943,0.2500264970853206,0.2500264970853206,0.24741069800040838]
valoresT2Y = [0.2535059116828267,0.2500264970853206,0.2500264970853206,0.23999768190673706]
valoresT3Y = [0.24934481164947234,0.2500264970853206,0.2500264970853206,0.23605651460507757]
valoresT4Y = [0.23580052062630666,0.24992050874403815,0.24992050874403815,0.2232387169172121]
valoresX = ['Facturación','Categorías','Productos','Costos de Envío']

fig, ax = plt.subplots()
plt.plot(valoresX, valoresT1Y, "green", label='Tienda 1')
plt.plot(valoresX, valoresT2Y, "purple", label='Tienda 2')
plt.plot(valoresX, valoresT3Y, "blue", label='Tienda 3')
plt.plot(valoresX, valoresT4Y, "red", label='Tienda 4')
plt.legend()

plt.plot(valoresX, valoresT1Y, "green" )
plt.plot(valoresX, valoresT2Y, "purple" )
plt.plot(valoresX, valoresT3Y, "blue" )
plt.plot(valoresX, valoresT4Y, "red" )
plt.xlabel("Ponderaciones de cada tienda")
plt.ylabel("Rendimiento")
plt.title("Rendimiento de cada tienda")

plt.show()

# %%
rendimiento_t1 = Rendimiento_FT1 + Rendimiento_CV1 + Rendimiento_PV1 + Rendimiento_F_menos_envios_t1
rendimiento_t2 = Rendimiento_FT2 + Rendimiento_CV2 + Rendimiento_PV2 + Rendimiento_F_menos_envios_t2
rendimiento_t3 = Rendimiento_FT3 + Rendimiento_CV3 + Rendimiento_PV3 + Rendimiento_F_menos_envios_t3
rendimiento_t4 = Rendimiento_FT4 + Rendimiento_CV4 + Rendimiento_PV4 + Rendimiento_F_menos_envios_t4

print(f"El rendimiento de la tienda 1 es: {rendimiento_t1}")
print(f"El rendimiento de la tienda 2 es: {rendimiento_t2}")
print(f"El rendimiento de la tienda 3 es: {rendimiento_t3}")
print(f"El rendimiento de la tienda 4 es: {rendimiento_t4}")
# Out:
# El rendimiento de la tienda 1 es: 1.0088124482124439
# El rendimiento de la tienda 2 es: 0.9935565877602051
# El rendimiento de la tienda 3 es: 0.9854543204251912
# El rendimiento de la tienda 4 es: 0.958880255031595

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo (puedes reemplazar con los reales de tus tiendas)
fruits = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
counts = [1.0088124482124439, 0.9935565877602051, 0.9854543204251912, 0.958880255031595]


bar_colors = ['tab:green', 'tab:blue', 'tab:purple', 'tab:red']

fig, ax = plt.subplots()

# Crear las barras una por una para que se muestre la leyenda
for fruit, count, label, color in zip(fruits, counts, bar_labels, bar_colors):
    ax.bar(fruit, count, label=label, color=color)

ax.set_ylabel('Rendimiento')
ax.set_title('Rendimiento Total de Cada Tienda')
plt.ylim(0.91, 1.01)

plt.show()

# %% [markdown]
# # **INFORME: “Análisis de Tiendas 1, 2, 3 y 4 de AluraStore Latam”**

# %% [markdown]
# **Introducción**
#
# El propósito de este informe es analizar el rendimiento de cuatro tiendas de AluraStore Latam, identificadas como Tienda 1, Tienda 2, Tienda 3 y Tienda 4. El objetivo es proporcionar al Sr. Juan una recomendación clara y justificada sobre cuál de estas tiendas debería considerar para una posible venta. Para ello, se han evaluado los siguientes parámetros:
#
# * Facturación total
# * Categorías de productos más y menos vendidas
# * Productos más y menos vendidos
# * Costos de envío

# %% [markdown]
# **Desarrollo del Análisis**
#
# **1. Análisis de facturación.**
#
# Los ingresos totales son un indicador fundamental de la salud financiera de cada tienda. A continuación, se detalla el desempeño de cada una:**
#
# *  **Tienda 1: 1.150.880.400**
# *  **Tienda 2: 1.116.343.500**
# *  **Tienda 3: 1.098.019.600**
# *  **Tienda 4: 1.038.375.700**
#
# ![G1.png](data:image/png;base64,...)

# %% [markdown]
# **2. Categorías de productos más y menos vendidas**
#
# El análisis de las categorías de productos revela las preferencias de los clientes y la demanda del mercado. En general, se observa un patrón consistente en todas las tiendas sobre los grupos de productos más y menos vendidos
#
# * **Categorías más vendida:  Muebles y Electrónicos.**
#
# * **Categorías menos vendidas:  Artículos Para el Hogar, Libros e Instrumentos musicales.**
#
# ![G2.png](data:image/png;base64,...)

# %% [markdown]
# **3. Calificaciones Promedio de los Clientes por Tienda**
#
# La satisfacción del cliente, reflejada en las calificaciones promedio, es crucial para la reputación y el éxito a largo plazo de una tienda:
# * **Tienda 1: 3.98**
# * **Tienda 2: 4.04**
# * **Tienda 3: 4.05**
# * **Tienda 4: 4.00**
#
# ![G3.png](data:image/png;base64,...)![G4.png](data:image/png;base64,...)

# %% [markdown]
# **4. Productos más y menos vendidos**
#
# La identificación de productos estrella y de bajo rendimiento puede guiar decisiones estratégicas de inventario y marketing:
#
# * **Tienda 1:**
#   * **Producto más vendido: Microondas**
#   * **Producto menos vendido: Auriculares**
# * **Tienda 2:**
#  * **Producto más vendido: Iniciando en programación**
#  * **Producto menos vendido: Juego de Mesa**
# * **Tienda 3:**
#  * **Producto más vendido: Kit de bancas**
#   * **Producto menos vendido: Bloques de construcción**
# * **Tienda 4:**
#   * **Producto más vendido: Cama box**
#   * **Producto menos vendido: Guitarra eléctrica**
#
# ![G5.png](data:image/png;base64,...)

# %% [markdown]
# **5. Costo de Envío Promedio para Cada Tienda**
#
# El costo de envío impacta la rentabilidad y puede influir en la decisión de compra del cliente, por lo mismo se deben tener en cuenta los factores que provoquen mayor o menores costos en este ámbito y así subsanarlos en lo posible:
#
# * **Tienda 1: 26.018,61**
# * **Tienda 2: 25.216,24**
# * **Tienda 3: 24.805,68**
# * **Tienda 4: 23.459,46**
# ![G6.png](data:image/png;base64,...)

# %% [markdown]
# **Análisis final y comparación de las 4 tiendas para la recomendación de venta**
#
# **Parámetros evaluados:**
#   * Facturación total
#   * Categorías de producto más y menos vendidas
#   * Productos más y menos vendidos
#   * Costos de envío
#
# **Rendimiento**
#
# Para facilitar la comparación de forma visual, se asigna un valor normalizado a través de una escala porcentual que se calcula teniendo en cuenta lo siguiente:
#
# Valor Tienda / Valor Total AluraStore Latam

# %% [markdown]
# **Rendimiento (R)**
#
# **Tienda 1:**
#   * Facturación total: **1.150.880.400** (0.2613487560413943)
#   * Ventas totales Categorías: **2.359**(0.2500264970853206)
#   * Ventas totales Productos: **2.359** (0.2500264970853206)
#   * Facturación total menos costos de envío: **1.089.502.500** (0.24741069800040838)
#
# **Tienda 2:**
#   * Facturación total: **1.116.343.500** (0.2535059116828267)
#   * Ventas totales Categorías: **2.359** (0.2500264970853206)
#   * Ventas totales Productos: **2.359** (0.2500264970853206)
#   * Facturación total menos costos de envío: **1.056.858.400** (0.23999768190673706)
#
# **Tienda 3:**
#   * Facturación total: **1.098.019.600** (0.24934481164947234)
#   * Ventas totales Categorías: **2.359**(0.2500264970853206)
#   * Ventas totales Productos: **2.359** (0.2500264970853206)
#   * Facturación total menos costos de envío: **1.039.503.000** (0.23605651460507757)
#
# **Tienda 4:**
#   * Facturación total: **1.038.375.700** (0.23580052062630666)
#   * Ventas totales Categorías: **2.358**(0.24992050874403815)
#   * Ventas totales Productos: **2.358** (0.24992050874403815)
#   * Facturación total menos costos de envío: **983.058.300** (0.2232387169172121)
#
# ![C1png.png](data:image/png;base64,...)![C2.png](data:image/png;base64,...)

# %% [markdown]
# **Conclusión final y recomendación para deshacerse de una tienda**
#
# Tras un análisis detallado de las cuatro tiendas de *AluraStore Latam*, considerando facturación total, ventas por categorías y productos, costos de envío y rendimiento neto, se observa lo siguiente:
#
# Tienda 1 lidera el grupo con la facturación más alta (aproximadamente 1.150 millones), representando cerca del 26,1% de las ventas totales, y mantiene un rendimiento neto favorable tras descontar costos. Su volumen de ventas y diversificación de productos la posicionan como una tienda sólida y rentable.
#
# Tienda 2 y Tienda 3 presentan cifras similares, con facturaciones superiores a los 1.090 millones y porcentajes que rondan el 25%. Ambas mantienen un buen desempeño en ventas totales y un rendimiento neto adecuado, lo que las convierte en tiendas con potencial para seguir contribuyendo positivamente al negocio.
#
# En contraste, **Tienda 4 muestra consistentemente los menores indicadores**, con una facturación total cercana a 1.038 millones (alrededor del 23,6%) y el rendimiento neto más bajo. Su menor volumen de ventas y desempeño general indican un aporte limitado en comparación con las otras tiendas.
#
# Por estas razones, se recomienda que el Sr. Juan considere vender o cerrar la Tienda 4 para optimizar recursos y enfocar esfuerzos en las tiendas con mejor desempeño. Las Tiendas 1, 2 y 3 deben mantenerse y potenciarse, ya que contribuyen significativamente a la rentabilidad y crecimiento del negocio.
#
# Adicionalmente, se sugiere analizar los factores que han afectado el rendimiento de la Tienda 4 para evaluar posibles mejoras o para maximizar su valor antes de la venta.
